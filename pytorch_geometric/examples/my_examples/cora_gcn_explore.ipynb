# %% [markdown]
# # Looking at the gcn.py file and Cora data in-depth

# %%
import os.path as osp
import torch
import torch_geometric
from torch_geometric.datasets import Planetoid
device = torch_geometric.device('auto')


path = osp.join(osp.dirname(osp.realpath(__file__)), '..', 'data', 'Planetoid')
dataset = Planetoid(path, args.dataset, transform=T.NormalizeFeatures())
data = dataset[0].to(device)
# Out:
# c:\Users\Chyi\anaconda3\envs\pyg\lib\site-packages\torch_geometric\typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# c:\Users\Chyi\anaconda3\envs\pyg\lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# c:\Users\Chyi\anaconda3\envs\pyg\lib\site-packages\torch_geometric\typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# c:\Users\Chyi\anaconda3\envs\pyg\lib\site-packages\torch_geometric\typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(
# c:\Users\Chyi\anaconda3\envs\pyg\lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 from torch_geometric.datasets import Planetoid
#       5 device = torch_geometric.device('auto')
# ----> 8 path = osp.join(osp.dirname(osp.realpath(__file__)), '..', 'data', 'Planetoid')
#       9 dataset = Planetoid(path, args.dataset, transform=T.NormalizeFeatures())
#      10 data = dataset[0].to(device)
#
# NameError: name '__file__' is not defined
